# %% [markdown]
# <a href="https://colab.research.google.com/github/Devan5622/simplelinearregression/blob/master/allerrorsandsklearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
data = pd.read_csv('floatdata.csv')
print(data.shape)
print(data.head())
X = data['X'].values
Y = data['Y'].values

X = X.reshape(-1,1)
Y = Y.reshape(-1,1)

mean_x = np.mean(X)
mean_y = np.mean(Y)
n = len(X)
numer = 0
denom = 0
for i in range(n):
 numer += (X[i] - mean_x) * (Y[i] - mean_y)
 denom += (X[i] - mean_x) ** 2
m = numer / denom
c = mean_y - (m * mean_x)
model = LinearRegression()
model.fit(X,Y)

y_predicted = model.predict(X)

rmse = mean_squared_error(Y, y_predicted)
r2 = r2_score(Y, y_predicted)

print('Slope:' ,model.coef_)
print('Intercept:', model.intercept_)

x = np.linspace(np.min(X)-1, np.max(X)+1, 100)
y = c + m * x
plt.plot(x, y, color='b', label='Regression Line')
plt.scatter(X, Y, c='g', label='Scatter Plot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.legend()
plt.show()

print('R2 score: ', r2)
for i in range(n):
    y_pred = c + m *X[i]
    ae= abs(Y[i] - y_pred)
    print("Absolute Error")
    print(ae)
sae=0
for i in range(n):
    y_pred = c + m *X[i]
    sae+= abs(Y[i] - y_pred)

print("SUM Absolute Error")
print(sae)    
    
    
sse = 0
for i in range(n):
    y_pred = c + m *X[i]
    sse += (Y[i] - y_pred) ** 2
print("SSE")
print(sse)

mse = 0
for i in range(n):
    y_pred = c + m *X[i]
    mse += (Y[i] - y_pred) ** 2
mse = mse/n
print("MSE")
print(mse)

rmse = 0
for i in range(n):
    y_pred = c + m*X[i]
    rmse += (Y[i] - y_pred) ** 2
rmse = np.sqrt(rmse/n)
print("RMSE")
print(rmse)
# Out:
#      <input type="file" id="files-03e31cf4-54ad-412a-841e-ef7d33850ceb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-03e31cf4-54ad-412a-841e-ef7d33850ceb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving floatdata.csv to floatdata.csv
# User uploaded file "floatdata.csv" with length 564 bytes
# (63, 2)
#      X      Y
# 0  108  392.5
# 1   19   46.2
# 2   13   15.7
# 3  124  422.2
# 4   40  119.4
# Slope: [[3.41382356]]
# Intercept: [19.99448576]
# R2 score:  0.8333466719794502
# Absolute Error
# [3.81256975]
# Absolute Error
# [38.6571334]
# Absolute Error
# [48.67419204]
# Absolute Error
# [21.10860721]
# Absolute Error
# [37.14742816]
# Absolute Error
# [43.68242868]
# Absolute Error
# [41.61242764]
# Absolute Error
# [9.7119844]
# Absolute Error
# [40.38345404]
# Absolute Error
# [11.16727864]
# Absolute Error
# [16.16360356]
# Absolute Error
# [64.24198336]
# Absolute Error
# [34.04654492]
# Absolute Error
# [58.91242764]
# Absolute Error
# [4.90874932]
# Absolute Error
# [20.22213288]
# Absolute Error
# [32.9737488]
# Absolute Error
# [10.42257288]
# Absolute Error
# [25.83595644]
# Absolute Error
# [14.48757236]
# Absolute Error
# [25.67742712]
# Absolute Error
# [2.0188978]
# Absolute Error
# [1.3811022]
# Absolute Error
# [17.03595644]
# Absolute Error
# [15.095369]
# Absolute Error
# [33.60874932]
# Absolute Error
# [21.84978]
# Absolute Error
# [9.82904304]
# Absolute Error
# [15.99125068]
# Absolute Error
# [4.45022]
# Absolute Error
# [19.99448576]
# Absolute Error
# [36.14007476]
# Absolute Error
# [25.87742712]
# Absolute Error
# [3.23639644]
# Absolute Error
# [66.40139592]
# Absolute Error
# [0.34654492]
# Absolute Error
# [10.63772292]
# Absolute Error
# [2.86036848]
# Absolute Error
# [21.04978]
# Absolute Error
# [15.01566272]
# Absolute Error
# [25.52580796]
# Absolute Error
# [22.42389936]
# Absolute Error
# [21.33874828]
# Absolute Error
# [6.49404252]
# Absolute Error
# [44.95478156]
# Absolute Error
# [86.56125172]
# Absolute Error
# [36.24654492]
# Absolute Error
# [19.56772188]
# Absolute Error
# [28.79492576]
# Absolute Error
# [9.66404356]
# Absolute Error
# [64.07051372]
# Absolute Error
# [28.62580796]
# Absolute Error
# [32.47419204]
# Absolute Error
# [39.10183916]
# Absolute Error
# [8.29492576]
# Absolute Error
# [14.304631]
# Absolute Error
# [72.09080744]
# Absolute Error
# [35.9737488]
# Absolute Error
# [36.6811022]
# Absolute Error
# [83.97698388]
# Absolute Error
# [27.7119844]
# Absolute Error
# [43.67286556]
# Absolute Error
# [78.74610168]
# SUM Absolute Error
# [1793.96772188]
# SSE
# [78796.74155103]
# MSE
# [1250.74192938]
# RMSE
# [35.36582997]
