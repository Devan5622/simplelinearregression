# %% [markdown]
# <a href="https://colab.research.google.com/github/Devan5622/simplelinearregression/blob/master/MultipleLinearRegressionusingdataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn]))) 
      
import pandas 
from sklearn import linear_model
import statsmodels.api as sm
import matplotlib.pyplot as plt
df =pandas.read_csv('cars.csv')
#Visualize linear relationship between Weight and CO2
plt.scatter(df['Weight'], df['CO2'], color='red')
plt.title('CO2 Vs Weight', fontsize=14)
plt.xlabel('Weight', fontsize=14)
plt.ylabel('CO2', fontsize=14)
plt.grid(True)
plt.show()


#Visualize linear relationship between Unemployment_Rate and Stock_Index_Price
plt.scatter(df['Volume'], df['CO2'], color='green')
plt.title('CO2 Vs Volume', fontsize=14)
plt.xlabel('Volume', fontsize=14)
plt.ylabel('CO2', fontsize=14)
plt.grid(True)
plt.show()

X = df[['Weight','Volume']] # here we have 2 variables for multiple regression. Ifyou just want to use one variable for simple linear regression, then use X = df['Interest_Rate'] forexample.Alternatively, you may add additional variables within the brackets
Y = df['CO2']


# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X,Y)
print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)



# prediction with sklearn
New_Interest_Rate = 3.8
New_Unemployment_Rate = 7.65
print ('Predicted Stock Index Price: \n', regr.predict([[New_Interest_Rate,New_Unemployment_Rate]]))
# Out:
#      <input type="file" id="files-5cbffc59-60ba-48c5-9fad-40e3e8cb78e0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5cbffc59-60ba-48c5-9fad-40e3e8cb78e0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cars.csv to cars (21).csv
# User uploaded file "cars.csv" with length 959 bytes
# Intercept:
#  79.69471929115937
# Coefficients:
#  [0.00755095 0.00780526]
# Predicted Stock Index Price:
#  [79.78312311]
